# %% [markdown]
# # Fake news detection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %% [markdown]
# # datasets

# %%
fake = pd.read_csv("data-set/Fake.csv")
true = pd.read_csv("data-set/True.csv")

# %%
fake.shape
# Out:
# (23481, 4)

# %%
true.shape
# Out:
# (21417, 4)

# %% [markdown]
# # Data cleaning and preparation

# %%
fake['target'] = 'fake'
true['target'] = 'true'

# %%
data = pd.concat([fake, true]).reset_index(drop = True)
data.shape
# Out:
# (44898, 5)

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data = data.reset_index(drop=True)

# %%
data.head()
# Out:
#                                                title  \
# 0  LIBERAL AMERICAN STUDENT Gets Brutal Lesson In...
# 1  WAR HAWK, ANTI-TRUMPER RINOS Join Dems To Inve...
# 2  Bipartisan Obamacare fix would cut U.S. defici...
# 3   SICKENING: Donald Trump Actually Hit On A 10-...
# 4  Kremlin says 'logical' that Putin, Trump will ...
#
#                                                 text       subject  \
# 0  Irish journalist and documentary filmmaker Ann...      politics
# 1  Pro man-made climate change, RINO Lindsay Grah...     left-news
# 2  WASHINGTON (Reuters) - A bipartisan Senate pro...  politicsNews
# 3  Donald Trump is a sexual predator, and more an...          News
# 4  MOSCOW (Reuters) - A Kremlin aide said on Wedn...     worldnews
#
#                 date target
# 0        May 3, 2017   fake
# 1       Dec 11, 2016   fake
# 2  October 25, 2017    true
# 3   October 12, 2016   fake
# 4  November 8, 2017    true

# %%
data.drop(["date"],axis=1,inplace=True)
data.head()
# Out:
#                                                title  \
# 0  LIBERAL AMERICAN STUDENT Gets Brutal Lesson In...
# 1  WAR HAWK, ANTI-TRUMPER RINOS Join Dems To Inve...
# 2  Bipartisan Obamacare fix would cut U.S. defici...
# 3   SICKENING: Donald Trump Actually Hit On A 10-...
# 4  Kremlin says 'logical' that Putin, Trump will ...
#
#                                                 text       subject target
# 0  Irish journalist and documentary filmmaker Ann...      politics   fake
# 1  Pro man-made climate change, RINO Lindsay Grah...     left-news   fake
# 2  WASHINGTON (Reuters) - A bipartisan Senate pro...  politicsNews   true
# 3  Donald Trump is a sexual predator, and more an...          News   fake
# 4  MOSCOW (Reuters) - A Kremlin aide said on Wedn...     worldnews   true

# %%
data.drop(["title"],axis=1,inplace=True)
data.head(2)
# Out:
#                                                 text    subject target
# 0  Irish journalist and documentary filmmaker Ann...   politics   fake
# 1  Pro man-made climate change, RINO Lindsay Grah...  left-news   fake

# %%
data['text'] = data['text'].apply(lambda x: x.lower())
data.head()
# Out:
#                                                 text       subject target
# 0  irish journalist and documentary filmmaker ann...      politics   fake
# 1  pro man-made climate change, rino lindsay grah...     left-news   fake
# 2  washington (reuters) - a bipartisan senate pro...  politicsNews   true
# 3  donald trump is a sexual predator, and more an...          News   fake
# 4  moscow (reuters) - a kremlin aide said on wedn...     worldnews   true

# %%
import string

def punctuation_removal(text):
    all_list = [char for char in text if char not in string.punctuation]
    clean_str = ''.join(all_list)
    return clean_str

data['text'] = data['text'].apply(punctuation_removal)

# %%
data.head()
# Out:
#                                                 text       subject target
# 0  irish journalist and documentary filmmaker ann...      politics   fake
# 1  pro manmade climate change rino lindsay graham...     left-news   fake
# 2  washington reuters  a bipartisan senate propos...  politicsNews   true
# 3  donald trump is a sexual predator and more and...          News   fake
# 4  moscow reuters  a kremlin aide said on wednesd...     worldnews   true

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')

data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data.head()
# Out:
#                                                 text       subject target
# 0  irish journalist documentary filmmaker ann mce...      politics   fake
# 1  pro manmade climate change rino lindsay graham...     left-news   fake
# 2  washington reuters bipartisan senate proposal ...  politicsNews   true
# 3  donald trump sexual predator evidence fact kee...          News   fake
# 4  moscow reuters kremlin aide said wednesday ent...     worldnews   true

# %% [markdown]
# # data exploration

# %%
print(data.groupby(['subject'])['text'].count())
data.groupby(['subject'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# subject
# Government News     1570
# Middle-east          778
# News                9050
# US_News              783
# left-news           4459
# politics            6841
# politicsNews       11272
# worldnews          10145
# Name: text, dtype: int64

# %%
print(data.groupby(['target'])['text'].count())
data.groupby(['target'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# target
# fake    23481
# true    21417
# Name: text, dtype: int64

# %%
from wordcloud import WordCloud

fake_data = data[data["target"] == "fake"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud

real_data = data[data["target"] == "true"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk import tokenize

token_space = tokenize.WhitespaceTokenizer()

def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency", color = 'blue')
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %% [markdown]
# # Most frequent words in fake news

# %%
counter(data[data["target"] == "fake"], "text", 20)

# %% [markdown]
# # Most frequent words in real news

# %%
counter(data[data["target"] == "true"], "text", 20)

# %% [markdown]
# # Modeling

# %%
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Peparing the data

# %%
X_train,X_test,y_train,y_test = train_test_split(data['text'], data.target, test_size=0.2, random_state=42)

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 98.82%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', DecisionTreeClassifier(criterion= 'entropy',
                                           max_depth = 20, 
                                           splitter='best', 
                                           random_state=42))])
model = pipe.fit(X_train, y_train)

prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 99.67%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', RandomForestClassifier(n_estimators=50, criterion="entropy"))])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 98.96%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization
